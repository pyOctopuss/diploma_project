# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

from pylab import rcParams
rcParams['figure.figsize'] = 12,8
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import matplotlib.pyplot as plt
import seaborn as sns


import pandas as pd
import numpy as np

from datetime import datetime, timedelta

import re

import os
from glob import glob
from tqdm import tqdm

import yaml
from yaml import dump
import uuid
import itertools

import matplotlib.pyplot as plt

# %%
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
import warnings
warnings.simplefilter(action="ignore")

# %% [markdown]
# ## classification

# %%
path_c = glob(f"/diploma_info/datalake/statistical_result/classification/*.csv")
path_c
# Out:
# ['/diploma_info/datalake/statistical_result/classification\\statistical_result_amazon_daily_20240330.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_amazon_daily_20240415.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_amazon_daily_20240416.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_amazon_daily_20240416_1.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_apple_daily_20240330.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_apple_daily_20240415.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_apple_daily_20240416.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_apple_daily_20240416_1.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_google_daily_20240330.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_google_daily_20240415.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_google_daily_20240416.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_google_daily_20240416_1.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_meta_daily_20240330.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_meta_daily_20240415.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_meta_daily_20240416.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_meta_daily_20240416_1.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_netflix_daily_20240330.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_netflix_daily_20240415.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_netflix_daily_20240416.csv',
#  '/diploma_info/datalake/statistical_result/classification\\statistical_result_netflix_daily_20240416_1.csv']

# %%
amazon_c = pd.DataFrame()
apple_c = pd.DataFrame()
google_c = pd.DataFrame()
meta_c = pd.DataFrame()
netflix_c = pd.DataFrame()


for company in ['amazon', 'apple', 'google', 'meta', 'netflix']:
    for p in path_c:
        if company in p:
            amazon_c = pd.concat([amazon_c, pd.read_csv(p)])
            apple_c = pd.concat([apple_c, pd.read_csv(p)])
            google_c = pd.concat([google_c, pd.read_csv(p)])
            meta_c = pd.concat([meta_c, pd.read_csv(p)])
            netflix_c = pd.concat([netflix_c, pd.read_csv(p)])

# %%
companies_c = {'amazon':amazon_c, 'apple':apple_c, 'google':google_c, 'meta':meta_c, 'netflix':netflix_c}
forecasted_days = 4
models_c = ['xgboost', 'lightgbm', 'random_forest', 'knear_neighbors', 'logistic_regression']

col = 'accuracy'

# %%
best_results_c_dict = {}

for i, (company, day, model) in enumerate(itertools.product(list(companies_c.items()), range(forecasted_days), models_c)):
#     print(i, _, day, model)

    company_name = company[0]
    _ = company[1]
    
    temp_df = _[_['model'] == model][_[col] == _[(_['forecasted_day'] == day)&(_['model'] == model)][col].max()]
    # [['features', 'hyperparameters']].values
    
    temp_df = temp_df.rename(columns={"Unnamed: 0": "exp_name"})
    
    d = {'company':company_name}
    d.update(dict(zip(temp_df.columns, temp_df.values[0])))
    
    best_results_c_dict[f'{i}'] = d
    
    
best_results_c = pd.DataFrame(best_results_c_dict).T

# %%
best_results_c[(best_results_c['company'] == 'amazon') & (best_results_c['forecasted_day'] == 3)]
# Out:
#    company                      exp_name forecasted_day n_days_forecasted  \
# 3   amazon      knear_neighbors_9151_d-3            3.0              24.0
# 15  amazon              xgboost_bb3d_d-3            3.0              24.0
# 16  amazon             lightgbm_b091_d-3            3.0              24.0
# 17  amazon        random_forest_9e1f_d-3            3.0              24.0
# 18  amazon      knear_neighbors_9151_d-3            3.0              24.0
# 19  amazon  logistic_regression_b276_d-3            3.0              24.0
#
#    n_forecasted_right accuracy                model train_start/duration  \
# 3                16.0    66.67      knear_neighbors           2015-01-01
# 15               15.0     62.5              xgboost           2015-01-01
# 16               16.0    66.67             lightgbm           2015-01-01
# 17               15.0     62.5        random_forest           2010-01-01
# 18               16.0    66.67      knear_neighbors           2015-01-01
# 19               16.0    66.67  logistic_regression           1997-05-15
#
#                                              features  \
# 3                     ['close_lag_1', 'volume_lag_1']
# 15  ['close_lag_1', 'close_max_3_days', 'close_min...
# 16  ['close_lag_1', 'close_max_3_days', 'close_min...
# 17                    ['close_lag_1', 'volume_lag_1']
# 18                    ['close_lag_1', 'volume_lag_1']
# 19  ['close_lag_1', 'close_max_3_days', 'close_min...
#
#                                       hyperparameters  \
# 3                   {'n_jobs': -1, 'n_neighbors': 50}
# 15  {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 16  {'eta': 0.3, 'max_depth': 7, 'metric': 'binary...
# 17  {'max_depth': 7, 'n_estimators': 5000, 'n_jobs...
# 18                  {'n_jobs': -1, 'n_neighbors': 50}
# 19  {'max_iter': 10, 'n_jobs': -1, 'random_state':...
#
#                          experiment_uuid
# 3   af49a062-fbca-11ee-9151-c0e434d84b22
# 15  af49a05d-fbca-11ee-bb3d-c0e434d84b22
# 16  af49a05f-fbca-11ee-b091-c0e434d84b22
# 17  af49a058-fbca-11ee-9e1f-c0e434d84b22
# 18  af49a062-fbca-11ee-9151-c0e434d84b22
# 19  6a500347-fb2b-11ee-b276-c0e434d84b22

# %%
best_best_results_c_dict = {}

for i, (company, day) in enumerate(itertools.product(list(companies_c.keys()), range(forecasted_days))):
    
    _ = best_results_c.copy()
    
    temp_df = _[_['company'] == company][_[col] == _[(_['forecasted_day'] == day)&(_['company'] == company)][col].max()]
    # [['features', 'hyperparameters']].values
    
    
    best_best_results_c_dict[f'{i}'] = dict(zip(temp_df.columns, temp_df.values[0]))
    
    
best_best_results_c = pd.DataFrame(best_best_results_c_dict).T

# %%
best_best_results_c
# Out:
#     company                      exp_name forecasted_day n_days_forecasted  \
# 0    amazon        random_forest_836d_d-0            0.0              27.0
# 1    amazon             lightgbm_b091_d-1            1.0              26.0
# 2    amazon              xgboost_a077_d-2            2.0              25.0
# 3    amazon      knear_neighbors_9151_d-3            3.0              24.0
# 4     apple              xgboost_84e2_d-0            0.0              27.0
# 5     apple              xgboost_af2c_d-1            1.0              26.0
# 6     apple              xgboost_af2c_d-2            2.0              25.0
# 7     apple              xgboost_af2c_d-3            3.0              24.0
# 8    google             lightgbm_a89c_d-0            0.0              27.0
# 9    google  logistic_regression_8584_d-1            1.0              26.0
# 10   google      knear_neighbors_b0aa_d-2            2.0              25.0
# 11   google  logistic_regression_8584_d-3            3.0              24.0
# 12     meta             lightgbm_8f1f_d-0            0.0              27.0
# 13     meta              xgboost_be57_d-1            1.0              26.0
# 14     meta        random_forest_8bad_d-2            2.0              25.0
# 15     meta             lightgbm_8f1f_d-0            0.0              27.0
# 16  netflix              xgboost_8c56_d-0            0.0              27.0
# 17  netflix  logistic_regression_babf_d-1            1.0              26.0
# 18  netflix        random_forest_b912_d-2            2.0              25.0
# 19  netflix             lightgbm_a8ee_d-3            3.0              24.0
#
#    n_forecasted_right accuracy                model train_start/duration  \
# 0                17.0    62.96        random_forest           2010-01-01
# 1                19.0    73.08             lightgbm           2015-01-01
# 2                16.0     64.0              xgboost           2010-01-01
# 3                16.0    66.67      knear_neighbors           2015-01-01
# 4                19.0    70.37              xgboost           2015-01-01
# 5                17.0    65.38              xgboost           2010-01-01
# 6                17.0     68.0              xgboost           2010-01-01
# 7                15.0     62.5              xgboost           2010-01-01
# 8                19.0    70.37             lightgbm           2010-01-01
# 9                18.0    69.23  logistic_regression           2004-08-19
# 10               19.0     76.0      knear_neighbors           2020-01-01
# 11               17.0    70.83  logistic_regression           2004-08-19
# 12               18.0    66.67             lightgbm           2010-01-01
# 13               18.0    69.23              xgboost           2010-01-01
# 14               17.0     68.0        random_forest           2010-01-01
# 15               18.0    66.67             lightgbm           2010-01-01
# 16               16.0    59.26              xgboost           2010-01-01
# 17               16.0    61.54  logistic_regression           2002-05-23
# 18               16.0     64.0        random_forest           2020-01-01
# 19               16.0    66.67             lightgbm           2020-01-01
#
#                                              features  \
# 0   ['close_lag_1', 'close_max_3_days', 'close_min...
# 1   ['close_lag_1', 'close_max_3_days', 'close_min...
# 2   ['close_lag_1', 'close_max_3_days', 'close_min...
# 3                     ['close_lag_1', 'volume_lag_1']
# 4                     ['close_lag_1', 'volume_lag_1']
# 5   ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 6   ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 7   ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 8                     ['close_lag_1', 'volume_lag_1']
# 9                     ['close_lag_1', 'volume_lag_1']
# 10                    ['close_lag_1', 'volume_lag_1']
# 11                    ['close_lag_1', 'volume_lag_1']
# 12                    ['close_lag_1', 'volume_lag_1']
# 13                    ['close_lag_1', 'volume_lag_1']
# 14                    ['close_lag_1', 'volume_lag_1']
# 15                    ['close_lag_1', 'volume_lag_1']
# 16  ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 17  ['close_lag_1', 'close_max_3_days', 'close_min...
# 18  ['close_lag_1', 'close_max_3_days', 'close_min...
# 19  ['close_lag_1', 'year', 'month', 'day', 'day_o...
#
#                                       hyperparameters  \
# 0   {'max_depth': 7, 'n_estimators': 5000, 'n_jobs...
# 1   {'eta': 0.3, 'max_depth': 7, 'metric': 'binary...
# 2   {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 3                   {'n_jobs': -1, 'n_neighbors': 50}
# 4   {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 5   {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 6   {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 7   {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 8   {'eta': 0.3, 'max_depth': 7, 'metric': 'binary...
# 9   {'max_iter': 10, 'n_jobs': -1, 'random_state':...
# 10                   {'n_jobs': -1, 'n_neighbors': 5}
# 11  {'max_iter': 10, 'n_jobs': -1, 'random_state':...
# 12  {'eta': 0.3, 'max_depth': 9, 'metric': 'binary...
# 13  {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 14  {'max_depth': 9, 'n_estimators': 10, 'n_jobs':...
# 15  {'eta': 0.3, 'max_depth': 9, 'metric': 'binary...
# 16  {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 17  {'max_iter': 10, 'n_jobs': -1, 'random_state':...
# 18  {'max_depth': 7, 'n_estimators': 10, 'n_jobs':...
# 19  {'eta': 0.3, 'max_depth': 9, 'metric': 'binary...
#
#                          experiment_uuid
# 0   af49a059-fbca-11ee-836d-c0e434d84b22
# 1   af49a05f-fbca-11ee-b091-c0e434d84b22
# 2   af49a055-fbca-11ee-a077-c0e434d84b22
# 3   af49a062-fbca-11ee-9151-c0e434d84b22
# 4   1a44aade-fbd0-11ee-84e2-c0e434d84b22
# 5   1a44aac9-fbd0-11ee-af2c-c0e434d84b22
# 6   1a44aac9-fbd0-11ee-af2c-c0e434d84b22
# 7   1a44aac9-fbd0-11ee-af2c-c0e434d84b22
# 8   0e20a838-fbd3-11ee-a89c-c0e434d84b22
# 9   6cccdb14-fb2b-11ee-8584-c0e434d84b22
# 10  0e20cf5c-fbd3-11ee-b0aa-c0e434d84b22
# 11  6cccdb14-fb2b-11ee-8584-c0e434d84b22
# 12  ac816902-fbd3-11ee-8f1f-c0e434d84b22
# 13  ac8168fc-fbd3-11ee-be57-c0e434d84b22
# 14  ac816905-fbd3-11ee-8bad-c0e434d84b22
# 15  ac816902-fbd3-11ee-8f1f-c0e434d84b22
# 16  2a1ece63-fbd8-11ee-8c56-c0e434d84b22
# 17  6e947e23-fb2b-11ee-babf-c0e434d84b22
# 18  2a1ece80-fbd8-11ee-b912-c0e434d84b22
# 19  2a1ece7f-fbd8-11ee-a8ee-c0e434d84b22

# %% [markdown]
# ## regression

# %%
path_r = glob(f"/diploma_info/datalake/statistical_result/regression/*.csv")

# %%
amazon_r = pd.read_csv(path_r[0])
apple_r = pd.read_csv(path_r[1])
google_r = pd.read_csv(path_r[2])
meta_r = pd.read_csv(path_r[3])
netflix_r = pd.read_csv(path_r[4])

# %%
companies_r = {'amazon':amazon_r, 'apple':apple_r, 'google':google_r, 'meta':meta_r, 'netflix':netflix_r}
forecasted_days = 4
models_r = ['xgboost', 'lightgbm', 'random_forest', 'linear_regression']

col = 'accuracy'

# %%
amazon_r
# Out:
#                      Unnamed: 0  forecasted_day  n_days_forecasted  \
# 0              xgboost_8e36_d-0             0.0               27.0
# 1              xgboost_8e36_d-1             1.0               26.0
# 2              xgboost_8e36_d-2             2.0               25.0
# 3              xgboost_8e36_d-3             3.0               24.0
# 4              xgboost_8e36_d-4             4.0               23.0
# ..                          ...             ...                ...
# 325  linear_regression_8eaa_d-0             0.0               27.0
# 326  linear_regression_8eaa_d-1             1.0               26.0
# 327  linear_regression_8eaa_d-2             2.0               25.0
# 328  linear_regression_8eaa_d-3             3.0               24.0
# 329  linear_regression_8eaa_d-4             4.0               23.0
#
#      n_days_err_less_5  %_days_err_less_5  accuracy  mean_abs_err  \
# 0                 24.0              88.89   97.3641        4.0304
# 1                 20.0              76.92   96.6573        4.9273
# 2                 18.0              72.00   95.9992        5.8332
# 3                 15.0              62.50   95.3375        7.1000
# 4                 15.0              65.22   94.7539        8.5026
# ..                 ...                ...       ...           ...
# 325               26.0              96.30   98.6052        0.6059
# 326               24.0              92.31   97.6296        1.5550
# 327               20.0              80.00   97.0132        2.4096
# 328               19.0              79.17   97.0992        3.6262
# 329               17.0              73.91   96.6665        5.1252
#
#      mean_rel_err  median_abs_err  median_rel_err  ...  q25_rel_err  \
# 0          2.6359            3.57           2.270  ...       1.2250
# 1          3.3427            3.86           2.370  ...       1.1925
# 2          4.0008            4.71           3.390  ...       1.5400
# 3          4.6625            5.54           3.565  ...       2.3450
# 4          5.2461            5.95           3.810  ...       3.0950
# ..            ...             ...             ...  ...          ...
# 325        1.3948            0.79           1.010  ...       0.7400
# 326        2.3704            0.63           1.790  ...       0.4350
# 327        2.9868            1.47           1.950  ...       1.1400
# 328        2.9008            2.47           1.875  ...       1.0425
# 329        3.3335            3.43           2.190  ...       1.1400
#
#      q75_abs_err  q75_rel_err  max_abs_err  max_rel_err              model  \
# 0         5.2000       3.3350        16.00         9.31            xgboost
# 1         5.6150       3.5850        20.67        12.03            xgboost
# 2         8.9300       5.6200        20.24        11.88            xgboost
# 3         8.9325       5.6900        20.46        12.00            xgboost
# 4        12.0300       7.4850        20.46        12.00            xgboost
# ..           ...          ...          ...          ...                ...
# 325       1.8000       1.4550        12.52         7.29  linear_regression
# 326       3.2850       2.9650        16.82         9.87  linear_regression
# 327       5.5400       3.9000        16.82         9.87  linear_regression
# 328       5.5175       3.8325        17.09        10.02  linear_regression
# 329       8.0400       5.1050        17.09        10.02  linear_regression
#
#     train_start/duration                                           features  \
# 0             2004-09-01                    ['close_lag_1', 'volume_lag_1']
# 1             2004-09-01                    ['close_lag_1', 'volume_lag_1']
# 2             2004-09-01                    ['close_lag_1', 'volume_lag_1']
# 3             2004-09-01                    ['close_lag_1', 'volume_lag_1']
# 4             2004-09-01                    ['close_lag_1', 'volume_lag_1']
# ..                   ...                                                ...
# 325           2004-09-01  ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 326           2004-09-01  ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 327           2004-09-01  ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 328           2004-09-01  ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 329           2004-09-01  ['close_lag_1', 'year', 'month', 'day', 'day_o...
#
#                                        hyperparameters  \
# 0    {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 1    {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 2    {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 3    {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 4    {'booster': 'gbtree', 'colsample_bytree': 1, '...
# ..                                                 ...
# 325  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 326  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 327  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 328  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 329  {'fit_intercept': False, 'n_jobs': -1, 'positi...
#
#                           experiment_uuid
# 0    7ee5c858-ec75-11ee-8e36-c0e434d84b22
# 1    7ee5c858-ec75-11ee-8e36-c0e434d84b22
# 2    7ee5c858-ec75-11ee-8e36-c0e434d84b22
# 3    7ee5c858-ec75-11ee-8e36-c0e434d84b22
# 4    7ee5c858-ec75-11ee-8e36-c0e434d84b22
# ..                                    ...
# 325  7ee5c899-ec75-11ee-8eaa-c0e434d84b22
# 326  7ee5c899-ec75-11ee-8eaa-c0e434d84b22
# 327  7ee5c899-ec75-11ee-8eaa-c0e434d84b22
# 328  7ee5c899-ec75-11ee-8eaa-c0e434d84b22
# 329  7ee5c899-ec75-11ee-8eaa-c0e434d84b22
#
# [330 rows x 21 columns]

# %%
best_results_r_dict = {}

for i, (company, day, model) in enumerate(itertools.product(list(companies_r.items()), range(forecasted_days), models_r)):
#     print(i, company[0], day, model)

    company_name = company[0]
    _ = company[1]
    
    temp_df = _[_['model'] == model][_[col] == _[(_['forecasted_day'] == day)&(_['model'] == model)][col].max()]
    # [['features', 'hyperparameters']].values
    temp_df = temp_df.rename(columns={"Unnamed: 0": "exp_name"})
    
    d = {'company':company_name}
    d.update(dict(zip(temp_df.columns, temp_df.values[0])))
    
    best_results_r_dict[f'{i}'] = d
    
    
best_results_r = pd.DataFrame(best_results_r_dict).T

# %%
best_results_r[(best_results_r['company'] == 'netflix') & (best_results_r['forecasted_day'] == 0)]
# Out:
#     company                    exp_name forecasted_day n_days_forecasted  \
# 64  netflix            xgboost_8544_d-0            0.0              27.0
# 65  netflix           lightgbm_a483_d-0            0.0              27.0
# 66  netflix      random_forest_85a3_d-0            0.0              27.0
# 67  netflix  linear_regression_9784_d-0            0.0              27.0
#
#    n_days_err_less_5 %_days_err_less_5 accuracy mean_abs_err mean_rel_err  \
# 64              25.0             92.59  97.9063      -0.7567       2.0937
# 65               0.0               0.0   0.1952     516.5193      99.8048
# 66              26.0              96.3   98.137       3.3822        1.863
# 67              26.0              96.3  98.5659       2.7019       1.4341
#
#    median_abs_err  ... q25_rel_err q75_abs_err q75_rel_err max_abs_err  \
# 64           -1.9  ...        0.62        3.19        2.47       54.78
# 65         491.19  ...       99.79      561.03       99.82      574.79
# 66           1.75  ...       0.615        9.04       2.035       53.45
# 67           1.34  ...        0.44       5.145        1.87       52.63
#
#    max_rel_err              model train_start/duration  \
# 64       10.05            xgboost           2004-09-01
# 65       99.83           lightgbm           2004-09-01
# 66        9.81      random_forest           2004-09-01
# 67        9.66  linear_regression           2004-09-01
#
#                                              features  \
# 64  ['close_lag_1', 'close_max_3_days', 'close_min...
# 65                    ['close_lag_1', 'volume_lag_1']
# 66  ['close_lag_1', 'close_max_3_days', 'close_min...
# 67  ['close_lag_1', 'year', 'month', 'day', 'day_o...
#
#                                       hyperparameters  \
# 64  {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 65  {'eta': 0.3, 'max_depth': 7, 'metric': 'binary...
# 66  {'max_depth': 7, 'n_estimators': 5000, 'n_jobs...
# 67  {'fit_intercept': True, 'n_jobs': -1, 'positiv...
#
#                          experiment_uuid
# 64  a7c7b980-ecec-11ee-8544-c0e434d84b22
# 65  a7c7b985-ecec-11ee-a483-c0e434d84b22
# 66  a7c7b99e-ecec-11ee-85a3-c0e434d84b22
# 67  a7c7b9ae-ecec-11ee-9784-c0e434d84b22
#
# [4 rows x 22 columns]

# %%
best_best_results_r_dict = {}

for i, (company, day) in enumerate(itertools.product(list(companies_r.keys()), range(forecasted_days))):
    
    _ = best_results_r.copy()
    
    temp_df = _[_['company'] == company][_[col] == _[(_['forecasted_day'] == day)&(_['company'] == company)][col].max()]
    # [['features', 'hyperparameters']].values
    
    
    best_best_results_r_dict[f'{i}'] = dict(zip(temp_df.columns, temp_df.values[0]))
    
    
best_best_results_r = pd.DataFrame(best_best_results_r_dict).T

# %%
best_best_results_r
# Out:
#     company                    exp_name forecasted_day n_days_forecasted  \
# 0    amazon      random_forest_a9b6_d-0            0.0              27.0
# 1    amazon      random_forest_a30f_d-1            1.0              26.0
# 2    amazon      random_forest_a30f_d-2            2.0              25.0
# 3    amazon      random_forest_a30f_d-3            3.0              24.0
# 4     apple  linear_regression_9ba3_d-0            0.0              27.0
# 5     apple      random_forest_a694_d-1            1.0              26.0
# 6     apple            xgboost_98a6_d-2            2.0              25.0
# 7     apple            xgboost_a6dc_d-3            3.0              24.0
# 8    google  linear_regression_90f8_d-0            0.0              27.0
# 9    google            xgboost_b3ac_d-1            1.0              26.0
# 10   google            xgboost_b3ac_d-2            2.0              25.0
# 11   google  linear_regression_9676_d-3            3.0              24.0
# 12     meta  linear_regression_8282_d-0            0.0              27.0
# 13     meta  linear_regression_8282_d-1            1.0              26.0
# 14     meta  linear_regression_8282_d-2            2.0              25.0
# 15     meta  linear_regression_8282_d-3            3.0              24.0
# 16  netflix  linear_regression_9784_d-0            0.0              27.0
# 17  netflix  linear_regression_bac3_d-1            1.0              26.0
# 18  netflix            xgboost_9a30_d-2            2.0              25.0
# 19  netflix            xgboost_9a30_d-3            3.0              24.0
#
#    n_days_err_less_5 %_days_err_less_5 accuracy mean_abs_err mean_rel_err  \
# 0               26.0              96.3   98.663       0.3307        1.337
# 1               24.0             92.31  97.6588       1.1085       2.3412
# 2               20.0              80.0   97.136        1.858        2.864
# 3               18.0              75.0  97.2925       3.0058       2.7075
# 4               27.0             100.0  98.9537      -0.2207       1.0463
# 5               24.0             92.31  98.2242      -0.7181       1.7758
# 6               24.0              96.0  97.7328      -1.8676       2.2672
# 7               22.0             91.67  97.6158       2.3642       2.3842
# 8               26.0              96.3  98.8737       0.1804       1.1263
# 9               25.0             96.15  97.8327       2.1412       2.1673
# 10              21.0              84.0  97.0116       2.9372       2.9884
# 11              20.0             83.33  96.8133       2.4983       3.1867
# 12              26.0              96.3   98.173        4.517        1.827
# 13              22.0             84.62  96.1192      12.8004       3.8808
# 14              17.0              68.0  94.7488      20.5628       5.2512
# 15              16.0             66.67   93.935      25.4633        6.065
# 16              26.0              96.3  98.5659       2.7019       1.4341
# 17              22.0             84.62  96.7188      11.0827       3.2812
# 18              18.0              72.0  95.5536      18.6272       4.4464
# 19              17.0             70.83  95.3592      19.0783       4.6408
#
#    median_abs_err  ... q25_rel_err q75_abs_err q75_rel_err max_abs_err  \
# 0           -0.44  ...       0.615        1.55       1.385       12.56
# 1             0.5  ...        0.42      2.1175      3.4225       16.18
# 2            1.17  ...        0.87        3.61        3.44       16.18
# 3            1.72  ...       0.675      4.2175      3.6525        16.4
# 4           -0.64  ...        0.42        1.36         1.3        5.91
# 5            0.06  ...      0.3325        1.55       2.715        10.5
# 6            -1.5  ...        0.82        1.54        3.61        7.29
# 7           2.455  ...       0.975      5.3025       3.115       11.39
# 8            0.72  ...        0.43        1.26       1.275        3.26
# 9             2.1  ...      1.2475       3.605      2.6975       13.91
# 10           3.11  ...        1.37         5.4        3.76       13.91
# 11          3.135  ...      1.6775      5.3875      4.0325       11.65
# 12           2.48  ...       0.385        5.79       1.955       80.02
# 13          7.485  ...        1.44      12.715      3.2475      100.68
# 14          11.15  ...        1.57       23.05        6.04      100.68
# 15         11.925  ...        2.17       31.55      8.0825      110.86
# 16           1.34  ...        0.44       5.145        1.87       52.63
# 17          2.935  ...      0.8425        9.83        2.67       84.93
# 18           2.86  ...        0.59       41.01        7.53       88.56
# 19           3.88  ...      0.7975      57.765     10.4075       78.85
#
#    max_rel_err              model train_start/duration  \
# 0         7.31      random_forest           2004-09-01
# 1          9.5      random_forest           2004-09-01
# 2          9.5      random_forest           2004-09-01
# 3         9.62      random_forest           2004-09-01
# 4         3.76  linear_regression           2004-09-01
# 5         5.58      random_forest           2004-09-01
# 6         5.39            xgboost           2004-09-01
# 7         5.88            xgboost           2004-09-01
# 8         7.94  linear_regression           2004-09-01
# 9         8.98            xgboost           2004-09-01
# 10        8.98            xgboost           2004-09-01
# 11        7.96  linear_regression           2004-09-01
# 12       16.85  linear_regression           2004-09-01
# 13       21.91  linear_regression           2004-09-01
# 14       21.91  linear_regression           2004-09-01
# 15       23.61  linear_regression           2004-09-01
# 16        9.66  linear_regression           2004-09-01
# 17       14.75  linear_regression           2004-09-01
# 18       15.38            xgboost           2004-09-01
# 19       13.82            xgboost           2004-09-01
#
#                                              features  \
# 0   ['close_lag_1', 'close_max_3_days', 'close_min...
# 1   ['close_lag_1', 'close_max_3_days', 'close_min...
# 2   ['close_lag_1', 'close_max_3_days', 'close_min...
# 3   ['close_lag_1', 'close_max_3_days', 'close_min...
# 4   ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 5   ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 6                     ['close_lag_1', 'volume_lag_1']
# 7   ['close_lag_1', 'close_max_3_days', 'close_min...
# 8   ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 9                     ['close_lag_1', 'volume_lag_1']
# 10                    ['close_lag_1', 'volume_lag_1']
# 11  ['close_lag_1', 'close_max_3_days', 'close_min...
# 12  ['close_lag_1', 'close_max_3_days', 'close_min...
# 13  ['close_lag_1', 'close_max_3_days', 'close_min...
# 14  ['close_lag_1', 'close_max_3_days', 'close_min...
# 15  ['close_lag_1', 'close_max_3_days', 'close_min...
# 16  ['close_lag_1', 'year', 'month', 'day', 'day_o...
# 17  ['close_lag_1', 'close_max_3_days', 'close_min...
# 18                    ['close_lag_1', 'volume_lag_1']
# 19                    ['close_lag_1', 'volume_lag_1']
#
#                                       hyperparameters  \
# 0   {'max_depth': 9, 'n_estimators': 5000, 'n_jobs...
# 1   {'max_depth': 7, 'n_estimators': 10, 'n_jobs':...
# 2   {'max_depth': 7, 'n_estimators': 10, 'n_jobs':...
# 3   {'max_depth': 7, 'n_estimators': 10, 'n_jobs':...
# 4   {'fit_intercept': True, 'n_jobs': -1, 'positiv...
# 5   {'max_depth': 7, 'n_estimators': 10, 'n_jobs':...
# 6   {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 7   {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 8   {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 9   {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 10  {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 11  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 12  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 13  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 14  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 15  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 16  {'fit_intercept': True, 'n_jobs': -1, 'positiv...
# 17  {'fit_intercept': False, 'n_jobs': -1, 'positi...
# 18  {'booster': 'gbtree', 'colsample_bytree': 1, '...
# 19  {'booster': 'gbtree', 'colsample_bytree': 1, '...
#
#                          experiment_uuid
# 0   7ee5c88c-ec75-11ee-a9b6-c0e434d84b22
# 1   7ee5c87d-ec75-11ee-a30f-c0e434d84b22
# 2   7ee5c87d-ec75-11ee-a30f-c0e434d84b22
# 3   7ee5c87d-ec75-11ee-a30f-c0e434d84b22
# 4   62f05269-ec7d-11ee-9ba3-c0e434d84b22
# 5   62f02b8b-ec7d-11ee-a694-c0e434d84b22
# 6   62f00451-ec7d-11ee-98a6-c0e434d84b22
# 7   62f0044f-ec7d-11ee-a6dc-c0e434d84b22
# 8   9f1633a6-ecdc-11ee-90f8-c0e434d84b22
# 9   9f163374-ecdc-11ee-b3ac-c0e434d84b22
# 10  9f163374-ecdc-11ee-b3ac-c0e434d84b22
# 11  9f1633a5-ecdc-11ee-9676-c0e434d84b22
# 12  25a0f36e-ece5-11ee-8282-c0e434d84b22
# 13  25a0f36e-ece5-11ee-8282-c0e434d84b22
# 14  25a0f36e-ece5-11ee-8282-c0e434d84b22
# 15  25a0f36e-ece5-11ee-8282-c0e434d84b22
# 16  a7c7b9ae-ecec-11ee-9784-c0e434d84b22
# 17  a7c7b9b0-ecec-11ee-bac3-c0e434d84b22
# 18  a7c7b976-ecec-11ee-9a30-c0e434d84b22
# 19  a7c7b976-ecec-11ee-9a30-c0e434d84b22
#
# [20 rows x 22 columns]
